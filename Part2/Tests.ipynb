# %%
# !python -m pytest tests/test_BLP.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.0rc3, pytest-9.0.2, pluggy-1.6.0 -- /Users/amirhosseinjavaheri/my_tensorflow_project/tf_env/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/amirhosseinjavaheri/my_tensorflow_project/Q3/JPMorgan-MLCOE-challenge-main/Part Final
# plugins: anyio-4.12.1
# collected 71 items
#
# tests/test_BLP.py::TestRcLogitDrawProbs::test_output_shape PASSED        [  1%]
# tests/test_BLP.py::TestRcLogitDrawProbs::test_probabilities_sum_to_one PASSED [  2%]
# tests/test_BLP.py::TestRcLogitDrawProbs::test_probabilities_non_negative PASSED [  4%]
# tests/test_BLP.py::TestRcLogitDrawProbs::test_sigma_zero_collapses_to_mnl PASSED [  5%]
# tests/test_BLP.py::TestRcLogitDrawProbs::test_outside_option_is_column_zero PASSED [  7%]
# tests/test_BLP.py::TestRcLogitDrawProbs::test_high_sigma_increases_variance_across_draws PASSED [  8%]
# ...

# %%
# !python -m pytest tests/test_LuSparseRandomLogit.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.0rc3, pytest-9.0.2, pluggy-1.6.0 -- /Users/amirhosseinjavaheri/my_tensorflow_project/tf_env/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/amirhosseinjavaheri/my_tensorflow_project/Q3/JPMorgan-MLCOE-challenge-main/Part Final
# plugins: anyio-4.12.1
# collected 123 items
#
# tests/test_LuSparseRandomLogit.py::TestGammaGibbsKernelSanity::test_is_calibrated_true PASSED [  0%]
# tests/test_LuSparseRandomLogit.py::TestGammaGibbsKernelSanity::test_avail_inside_stored PASSED [  1%]
# tests/test_LuSparseRandomLogit.py::TestGammaGibbsKernelSanity::test_avail_inside_dtype PASSED [  2%]
# tests/test_LuSparseRandomLogit.py::TestGammaGibbsKernelSanity::test_bootstrap_results_is_namedtuple PASSED [  3%]
# tests/test_LuSparseRandomLogit.py::TestGammaGibbsKernelSanity::test_one_step_shape PASSED [  4%]
# ...

# %%
# !python -m pytest tests/test_DeepHalo_MCEM_Core.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.0rc3, pytest-9.0.2, pluggy-1.6.0 -- /Users/amirhosseinjavaheri/my_tensorflow_project/tf_env/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/amirhosseinjavaheri/my_tensorflow_project/Q3/JPMorgan-MLCOE-challenge-main/Part Final
# plugins: anyio-4.12.1
# collected 115 items
#
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_returns_three_tensors PASSED [  0%]
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_sigma_t_shape PASSED [  1%]
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_probs_shape PASSED [  2%]
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_ll_vec_shape PASSED [  3%]
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_sigma_t_dtype PASSED [  4%]
# tests/test_DeepHalo_MCEM_Core.py::TestLikelihoodShapeSanity::test_ll_vec_dtype PASSED [  5%]
# ...

# %%
# !python -m pytest tests/test_GenerateData.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.0rc3, pytest-9.0.2, pluggy-1.6.0 -- /Users/amirhosseinjavaheri/my_tensorflow_project/tf_env/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/amirhosseinjavaheri/my_tensorflow_project/Q3/JPMorgan-MLCOE-challenge-main/Part Final
# plugins: anyio-4.12.1
# collected 220 items
#
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_T PASSED [  0%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_J PASSED [  0%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_Nt PASSED [  1%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_D PASSED [  1%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_xi_bar PASSED [  2%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_default_seed PASSED [  2%]
# tests/test_GenerateData.py::TestSimParamsDefaults::test_beta_mean_is_ndarray PASSED [  3%]
# ...
