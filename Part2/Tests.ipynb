# %%
# !python -m pytest tests/Bayesian_Sparse_Deephalo_Tests.py -v
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.0rc3, pytest-9.0.2, pluggy-1.6.0 -- /Users/amirhosseinjavaheri/my_tensorflow_project/tf_env/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/amirhosseinjavaheri/Q3/Final_files/Part2
# configfile: pyproject.toml
# plugins: anyio-4.12.1
# collected 92 items
#
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestSimParams::test_beta_mean_length_matches_D PASSED [  1%]
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestSimParams::test_custom_override PASSED [  2%]
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestSimParams::test_defaults PASSED [  3%]
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestSimParams::test_sigma_beta_length_matches_D PASSED [  4%]
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestGenerateDataTf::test_counts_sum_to_Nt PASSED [  5%]
# tests/Bayesian_Sparse_Deephalo_Tests.py::TestGenerateDataTf::test_dataset_choices_in_range PASSED [  6%]
# ...
